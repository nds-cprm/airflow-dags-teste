# %%
import geopandas as gpd

# %%
geodata = gpd.read_parquet("litoestratigrafia_geometria.parquet")
geodata.set_crs("EPSG:4326", inplace=True)
geodata.info()

# %%
geodata.geometry.is_valid.value_counts()

# %%
geodata.crs
